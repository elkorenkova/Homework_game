# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from ydata_profiling import ProfileReport
import sweetviz as sv
import dtale

# %%
data = pd.read_csv('C:\Temp\Pythone/wine.csv')
data.head(1)
#data.nunique()
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 12.9+ MB

# %%
data.max()
# Out:
# C:\Users\e.korenkova\AppData\Local\Temp\ipykernel_16420\2904433368.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.max()
# description    “Wow” is the first word that comes to mind whe...
# points                                                       100
# price                                                     3300.0
# title                            Štoka 2011 Izbrani Teran (Kras)
# winery                                                     Štoka
# dtype: object

# %%
dupl_columns = list(data.columns)

mask = data.duplicated(subset=dupl_columns)
wine_duplicates = data[mask]
print(f'Число найденных дубликатов: {wine_duplicates.shape[0]}')

wine_dedupped = data.drop_duplicates(subset=dupl_columns)
print(f'Результирующее число записей: {wine_dedupped.shape[0]}')
# Out:
# Число найденных дубликатов: 9983
# Результирующее число записей: 119988

# %%
profile = ProfileReport(wine_dedupped, title="Pandas Profiling Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.1.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-04-09 13:01:09.671658&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("C:\Temp\Pythone/your_report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
report = sv.analyze(wine_dedupped)
report.show_html()
# Out:
# c:\Users\e.korenkova\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# c:\Users\e.korenkova\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
#                                              |          | [  0%]   00:00 -> (? left)
# c:\Users\e.korenkova\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# ...

# %%
d = dtale.show(wine_dedupped)
d
# Out:
# c:\Users\e.korenkova\AppData\Local\Programs\Python\Python311\Lib\site-packages\dtale\views.py:755: FutureWarning:
#
# ['country', 'designation', 'province', 'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'variety'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LT-KORENKOVA1:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2023-04-09 18:20:36,035 - INFO     - Executing shutdown due to inactivity...
# 2023-04-09 18:20:48,538 - INFO     - Executing shutdown...
# 2023-04-09 18:20:48,570 - ERROR    - Exception on /shutdown [GET]
# Traceback (most recent call last):
#   File "c:\Users\e.korenkova\AppData\Local\Programs\Python\Python311\Lib\site-packages\flask\app.py", line 2528, in wsgi_app
# ...
